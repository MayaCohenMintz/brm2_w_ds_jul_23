# %%
import cv2
from matplotlib import pyplot as plt
image = cv2.imread("/home/ben/python/brm2/data/atlases/whs_sd_rat_39um/whs_sd_rat_39um_500.tif", cv2.IMREAD_UNCHANGED)
plt.imshow(image, cmap='gray')

# %%
print(image.min(), image.max())
# Out:
# 0.0 0.61798817
